# %% [markdown]
# <b><h1><font color = "red">Bartys Test NoteBook.</font> </h1></b> </br> Contains tests. Not to be run within ROS.

# %%
import numpy as np
import cv2

# %%
img = cv2.imread('Refference Images/WithRedDot/Grid2.jpg')
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
#Red Green Blue
# define range of blue color in HSV
lower_blue = np.array([90,130,80])
upper_blue = np.array([115,255,255])

lower_yellow = np.array([20,204,150])
upper_yellow = np.array([54,255,255])

# lower mask (0-10)
lower_red = np.array([0,110,139])
upper_red = np.array([10,255,255])
maskr = cv2.inRange(hsv, lower_red, upper_red)

'''
# upper mask (170-180)
lower_red = np.array([170,10,10])
upper_red = np.array([180,255,255])
maskr2 = cv2.inRange(hsv, lower_red, upper_red)

'''


# Threshold the HSV image to get only blue colors
maskb = cv2.inRange(hsv, lower_blue, upper_blue)
masky = cv2.inRange(hsv, lower_yellow, upper_yellow) #Needs tweeaking
maskr = cv2.inRange(hsv, lower_red, upper_red)

# %%
stack = np.hstack((maskb, masky,maskr))
cv2.namedWindow("image", cv2.WINDOW_NORMAL)
cv2.imshow('image',stack)
cv2.namedWindow("image2", cv2.WINDOW_NORMAL)
cv2.imshow('image2',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import sys
import numpy as np

def nothing(x):
    pass

# Load in image
image = cv2.imread('Refference Images/WithRedDot/Grid1.jpg')

# Create a window
cv2.namedWindow('image', cv2.WINDOW_NORMAL)

# create trackbars for color change
cv2.createTrackbar('HMin','image',0,179,nothing) # Hue is from 0-179 for Opencv
cv2.createTrackbar('SMin','image',0,255,nothing)
cv2.createTrackbar('VMin','image',0,255,nothing)
cv2.createTrackbar('HMax','image',0,179,nothing)
cv2.createTrackbar('SMax','image',0,255,nothing)
cv2.createTrackbar('VMax','image',0,255,nothing)

# Set default value for MAX HSV trackbars.
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize to check if HSV min/max value changes
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

output = image
wait_time = 33

while(1):

    # get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin','image')
    sMin = cv2.getTrackbarPos('SMin','image')
    vMin = cv2.getTrackbarPos('VMin','image')

    hMax = cv2.getTrackbarPos('HMax','image')
    sMax = cv2.getTrackbarPos('SMax','image')
    vMax = cv2.getTrackbarPos('VMax','image')

    # Set minimum and max HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Create HSV Image and threshold into a range.
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    output = cv2.bitwise_and(image,image, mask= mask)

    # Print if there is a change in HSV value
    if( (phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display output image
    cv2.imshow('image',output)

    # Wait longer to prevent freeze for videos.
    if cv2.waitKey(wait_time) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 29 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 28 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 7, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 11, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 9, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 25 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 20 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 19 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 18 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 17 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 12 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 11 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 10 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 9 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 7 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 5 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 4 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 3 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 1 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 176 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 171 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 167 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 157 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 146 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 127 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 79 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 69 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 62 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 55 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 48 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 45 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 43 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 35 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 27 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 20 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 16 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 11 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 10 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 11 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 14 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 12 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 11 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 10 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 7 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 6 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 5 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 4 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 5 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 4 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 3 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 2 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 250, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 248, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 216, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 179, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 169, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 131, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 114, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 111, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 153, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 236, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 237, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 36, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 40, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 41, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 47, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 49, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 52, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 53, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 56, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 58, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 60, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 61, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 0 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 2 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 3 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 4 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 5 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 12 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 13 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 15 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 18 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 17 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 14 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 12 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 11 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 10 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 10 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 11 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 10 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 62, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 59, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 55, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 50, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 46, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 44, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 43, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 45, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 61, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 68, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 74, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 76, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 88, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 100, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 107, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 113, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 119, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 128, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 129, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 130, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 123, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 110, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 100, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 90, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 84, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 83, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 84, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 102, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 113, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 119, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 147, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 166, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 182, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 184, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 185, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 195, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 199, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 201, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 205, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 206, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 207, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 204, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 201, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 185, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 179, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 170, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 160, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 153, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 151, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 148, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 143, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 142, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 141, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 130, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 125, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 124, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 123, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 120, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 119, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 117, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 114, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 112, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 7 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 6 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 5 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 4 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 3 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 2 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 2 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 3 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 4 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 5 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 2 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 254, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 238, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 222, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 214, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 177, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 147, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 133, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 132, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 139, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 165, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 192, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 203, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 215, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 216, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 217, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 216, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 211, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 208, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 200, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 193, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 187, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 184, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 183, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 184, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 190, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 200, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 207, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 209, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 210, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 211, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 214, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 221, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 231, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 245, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 252, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 0), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 1), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 9), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 14), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 19), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 22), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 33), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 42), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 54), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 64), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 73), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 80), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 1 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 2 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 3 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 4 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 5 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 7 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 8 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 82), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 86), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 95), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 98), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 110), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 134), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 143), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 144), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 146), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin = 145), (hMax = 9 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 111, vMin =

# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 232)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 220)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 211)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 210)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 203)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 201)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 198)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 185)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 178)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 202)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 210)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 213)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 212)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 207)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 205)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 40 , sMax = 255, vMax = 204)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 41 , sMax = 255, vMax = 204)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 42 , sMax = 255, vMax = 204)
# (hMin = 22 , sMin = 204, vMin = 154), (hMax = 43 , sMax = 255, vMax = 204)
# ...
# (hMin = 13 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 6 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 2 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 8 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 13 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 15 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 27 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 23 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 21 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 24 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 26 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 30 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 34 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 154), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 144), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 126), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 110), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 93), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 87), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 86), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 85), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 82), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 78), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 75), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 78), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 87), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 96), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 101), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 100), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 86), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 77), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 76), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 77), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 78), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 155 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 143 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 131 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 95 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 93 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 94 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 100 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 35 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 36 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 48 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 64 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 73 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 76 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 78 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 81 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 85 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 86 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 88 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 89 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 95 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 96 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 101 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 103 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 98 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 94 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 91 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 79), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 80), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 81), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 124 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 133 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 137 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 142 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 144 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 141 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 131 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 105 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 104 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 103 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 102 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 103 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 105 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 106 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 107 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 112 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 117 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 118 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 113 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 116 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 115 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 254, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 243, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 236, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 222, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 214, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 209, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 202, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 196, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 194, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 201, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 212, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 223, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 234, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 241, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 248, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 253, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 254)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 253)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 249)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 244)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 237)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 233)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 232)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 226)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 221)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 216)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 212)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 207)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 202)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 197)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 185)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 178)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 174)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 169)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 164)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 153)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 148)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 149)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 168)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 184)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 199)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 211)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 214)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 215)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 216)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 217)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 218)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 219)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 222)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 225)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 226)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 227)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 229)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 233)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 234)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 238)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 253)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 246)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 222)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 215)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 214)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 215)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 216)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 232)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 251)
# (hMin = 90 , sMin = 0, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 3, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 9, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 17, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 21, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 25, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 27, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 34, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 43, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 53, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 60, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 71, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 87, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 96, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 101, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 107, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 110, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 112, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 123, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 129, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 130, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 133, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 130, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 129, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 128, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 129, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 90 , sMin = 130, vMin = 82), (hMax = 114 , sMax = 255, vMax = 255)
